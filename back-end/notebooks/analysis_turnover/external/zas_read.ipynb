# %%
import duckdb

# %load_ext sql
conn = duckdb.connect()
# %sql conn --alias duckdb
# %sql INSTALL spatial; LOAD spatial;
# %sql INSTALL excel; LOAD excel;
# %config SqlMagic.displaylimit = None
# Out:
# Running query in 'duckdb'
# Running query in 'duckdb'
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %%sql
# DROP TABLE IF EXISTS YSL_data;
# CREATE TABLE IF NOT EXISTS YSL_data AS
# SELECT *
# FROM st_read('../ZAS rapport Incisionxlsx.xlsx')
# Out:
# Running query in 'duckdb'
# +-------+
# | Count |
# +-------+
# | 89346 |
# +-------+

# %%
# %%sql
# SELECT  *
# FROM YSL_data
# LIMIT 10
# Out:
# Running query in 'duckdb'
# +-----------------------+-------------------------+---------------------------------------+----------------+-------------------+-------------------+---------------------+---------------------+---------------------+----------------------+--------------------------+------------------------------+--------------------------------------------------------------------------------------------------------+---------------------+--------------------------+-------------------------+-----------------------+----------------------+---------------+------------+-------------------------------+----------------------------+----------------------+--------------------+---------------------+--------------------+---------------------+--------------------+----------------+------------+------------+----------------+-----------------+------------------------+--------------------------+-------------------+-----------------------------+-----------------+
# | type (dag)opname naam | geplande operateur naam | geplande operateur - specialisme naam |  campus naam   | operatiezaal code | operatiezaal naam |    aanvraagdatum    |     opnamedatum     |    operatiedatum    | operatiedatum - jaar | operatiedatum - maand nr | operatiedatum - weekdag naam |                                            verrichting naam                                            |   prioriteit naam   | geplande startdatum/tijd | geplande einddatum/tijd | reële startdatum/tijd | reële einddatum/tijd | geplande duur | reële duur | geplande duur incl wisseltijd | reële duur incl wisseltijd | sessieblauwdruk naam | 04 OK aankomsttijd | inleiding starttijd | inleiding eindtijd | operateur starttijd | operateur eindtijd | OK vertrektijd | bruto duur | netto duur | duur inleiding | duur uitleiding | duur in- en uitleiding | duur besteld tot holding | duur tot afdeling |        afdeling na OK       | # verrichtingen |
# +-----------------------+-------------------------+---------------------------------------+----------------+-------------------+-------------------+---------------------+---------------------+---------------------+----------------------+--------------------------+------------------------------+--------------------------------------------------------------------------------------------------------+---------------------+--------------------------+-------------------------+-----------------------+----------------------+---------------+------------+-------------------------------+----------------------------+----------------------+--------------------+---------------------+--------------------+---------------------+--------------------+----------------+------------+------------+----------------+-----------------+------------------------+--------------------------+-------------------+-----------------------------+-----------------+
# |     Dagziekenhuis     |        David Raes       |              Cardiologie              | ZAS Middelheim |     0000113751    |      MI OK B4     | 2024-06-18 00:00:00 | 2024-07-10 00:00:00 | 2024-07-10 00:00:00 |         2024         |            7             |           Woensdag           |                                     wisselen van 1-kamer pacemaker                                     |       Onbekend      |   2024-07-10 09:10:00    |   2024-07-10 10:10:00   |  2024-07-10 09:26:00  | 2024-07-10 10:28:00  |       60      |     62     |               70              |             67             |      PICASSO VM      |       09:26        |       Onbekend      |      Onbekend      |        09:45        |       10:13        |     10:28      |     62     |     28     |      None      |        15       |          None          |            16            |         15        |  MILI Cardiologie Lounge In |        1        |
# |    Klinische opname   |   Tony Van Havenbergh   |             Neurochirurgie            | ZAS Augustinus |        SA15       |      SA OK 15     | 2024-02-24 00:00:00 | 2024-02-24 00:00:00 | 2024-02-25 00:00:00 |         2024         |            2             |            Zondag            |                                Chronisch subduraal hematoom via boorgat                                |    Spoed < 48 uur   |   2024-02-25 00:01:00    |   2024-02-25 01:01:00   |  2024-02-25 14:12:00  | 2024-02-25 15:30:00  |      None     |     78     |              None             |            100             |       Spoed SA       |       14:12        |        14:16        |       14:26        |        14:38        |       15:20        |     15:30      |     78     |     42     |       10       |        10       |           20           |           None           |         1         |   C08SA NKO/Neurochirurgie  |        1        |
# |    Klinische opname   |       Thomas Adams      |                Urologie               | ZAS Augustinus |        SA08       |      SA OK 08     | 2024-09-19 00:00:00 | 2024-09-18 00:00:00 | 2024-09-19 00:00:00 |         2024         |            9             |          Donderdag           |                             TUR blaas: transurethrale resectie blaastumor                              |    Spoed < 48 uur   |   2024-09-19 14:55:00    |   2024-09-19 15:37:00   |  2024-09-19 14:26:00  | 2024-09-19 15:08:00  |      None     |     42     |              None             |             52             |    Urologie OKSA     |       14:26        |        14:37        |       14:47        |        14:45        |       15:02        |     15:08      |     42     |     17     |       10       |        6        |           16           |            13            |         11        |    C09SA Gynaeco/Urologie   |        1        |
# |     Dagziekenhuis     |       Klara Caers       |          Plastische chirurgie         | ZAS Augustinus |        SAD1       |     SA CDC 01     | 2024-02-28 00:00:00 | 2024-03-08 00:00:00 | 2024-03-08 00:00:00 |         2024         |            3             |           Vrijdag            |                 excisie van een maligne tumor met reconstructie met/zonder vriescoupe                  |       Onbekend      |   2024-03-08 10:00:00    |   2024-03-08 11:00:00   |  2024-03-08 10:33:00  | 2024-03-08 11:43:00  |       60      |     70     |               70              |             70             |   Plastische OKSA    |       10:33        |       Onbekend      |      Onbekend      |        10:52        |       11:35        |     11:43      |     70     |     43     |      None      |        8        |          None          |            6             |        None       |            CDC SA           |        1        |
# |    Klinische opname   |  Christophe Olyslaegers |               Orthopedie              | ZAS Augustinus |        SA03       |      SA OK 03     | 2024-08-30 00:00:00 | 2024-08-30 00:00:00 | 2024-08-30 00:00:00 |         2024         |            8             |           Vrijdag            | ORIF met Intramedullaire nagel voor Intertrochantere / pertrochantere/subtrochantere femurhalsfractuur |    Spoed < 8 uur    |   2024-08-30 14:41:00    |   2024-08-30 16:01:00   |  2024-08-30 14:23:00  | 2024-08-30 15:58:00  |      None     |     95     |              None             |             95             | Orthopedie OKSA 17u  |       14:23        |        14:41        |       14:51        |        15:03        |       15:44        |     15:58      |     95     |     41     |       10       |        14       |           24           |            13            |         22        | C10SA Orthopedie/Plastische |        1        |
# +-----------------------+-------------------------+---------------------------------------+----------------+-------------------+-------------------+---------------------+---------------------+---------------------+----------------------+--------------------------+------------------------------+--------------------------------------------------------------------------------------------------------+---------------------+--------------------------+-------------------------+-----------------------+----------------------+---------------+------------+-------------------------------+----------------------------+----------------------+--------------------+---------------------+--------------------+---------------------+--------------------+----------------+------------+------------+----------------+-----------------+------------------------+--------------------------+-------------------+-----------------------------+-----------------+
